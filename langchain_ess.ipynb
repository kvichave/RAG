# %%
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from langchain_core.messages import HumanMessage, SystemMessage

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model=ChatGoogleGenerativeAI(api_key="AIzaSyBEfvDwes9xg7YT0rdSxFpNdrzBwHigp8A",model="gemini-2.5-flash",temperature=0)

# %%
message=[SystemMessage(content="Hi you are a bot"),HumanMessage(content="Hi, how are you buddy?")]

# %%
response=model.invoke(message)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
parser=StrOutputParser()

# %%
parser.invoke(response)
# Out:
# 'Hi there!\n\nAs an AI, I don\'t have feelings or a physical state like humans do, so I don\'t "feel" good or bad. However, I\'m fully operational and ready to assist you!\n\nHow are *you* doing today? And what can I help you with?'
